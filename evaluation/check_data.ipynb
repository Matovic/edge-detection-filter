# %%
# %matplotlib inline

import cv2
import matplotlib.pyplot as plt
import numpy as np
#import cv2
#from collections import Counter
#from skimage.color import rgb2lab, deltaE_cie76
import os

# %%
#cv2.namedWindow("output", cv2.WINDOW_NORMAL)    # Create window with freedom of dimensions
img = cv2.imread('../output/4987_21_HE/4987_21_HE_P2_T64_LT1_R100.tif')
print("The type of this input is {}".format(type(img)))
print("Shape: {}".format(img.shape))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

#ims = cv2.resize(img, (960, 540))                # Resize image
#cv2.imshow('output',img)
#cv2.waitKey(0)          # Display the image infinitely until any keypress
#cv2.destroyAllWindows()
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (7677, 39179, 3)

# %%
#cv2.namedWindow("output", cv2.WINDOW_NORMAL)    # Create window with freedom of dimensions
img = cv2.imread('../output/4987_21_HE/4987_21_HE_P2_T64_LT50_R2.tif')
print("The type of this input is {}".format(type(img)))
print("Shape: {}".format(img.shape))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

#ims = cv2.resize(img, (960, 540))                # Resize image
#cv2.imshow('output',img)
#cv2.waitKey(0)          # Display the image infinitely until any keypress
#cv2.destroyAllWindows()
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (7677, 39179, 3)
